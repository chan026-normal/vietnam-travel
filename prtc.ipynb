# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 베트남 전문 여행 가이드입니다. 실용적인 여행 정보를 한국어로 안내해주세요."},
        {"role": "user", "content": "하노이 3박 4일 일정 짜줘"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 하노이에서의 3박 4일 여행 일정을 아래와 같이 추천드립니다. 이 일정은 하노이의 주요 명소와 맛집, 그리고 근교 관광지를 포함하고 있습니다.
#
# ### 1일차: 하노이 도착 및 시내 관광
#
# - **오전**
#   - 하노이에 도착 후 호텔 체크인
#   - 호안키엠 호수 산책 및 응옥썬 사원 방문
#
# - **점심**
#   - 호안키엠 호수 근처의 전통 베트남 식당에서 '포(Phở)'를 즐겨보세요.
#
# - **오후**
#   - 문묘(문사사) 방문: 베트남의 최초의 대학으로, 역사와 문화에 대해 배울 수 있습니다.
#   - 하노이 대성당 방문: 고딕 양식의 아름다운 건축물
#
# - **저녁**
#   - 구시가지 탐방: 다양한 거리 음식과 쇼핑 즐기기
#   - 추천 음식: '반쎄오(Bánh xèo)'(베트남식 팬케이크)
#
# ### 2일차: 하롱베이 당일 투어
#
# - **오전**
#   - 아침 일찍 하롱베이로 출발 (차로 약 2.5시간 소요)
#   - 하롱베이 항구 도착 및 보트 탑승
#
# - **오후**
#   - 하롱베이 크루즈: 환상적인 석회암 동굴과 섬 탐방
#   - 수영할 수 있는 기회도 있으니 수영복 지참하세요.
#
# - **저녁**
#   - 하롱베이에서 식사 후 하노이로 귀환
#
# ### 3일차: 하노이 문화 탐방
#
# - **오전**
#   - 베트남 민속학 박물관 또는 하노이 역사 박물관 방문
#   - 파르타이 사원 (Tran Quoc Pagoda) 방문: 하노이에서 가장 오래된 사원 중 하나
#
# - **점심**
#   - 전통 베트남 요리 레스토랑에서 식사
#
# - **오후**
#   - 하노이 인민극장 또는 water puppet show(물인형극) 관람
#   - 쇼핑을 원하신다면, 동쑤언 시장이나 롱비엔 시장 방문
#
# - **저녁**
#   - 하노이 카페 거리 탐방 및 커피 한 잔: 베트남식 커피를 꼭 맛보세요.
#
# ### 4일차: 하노이에서의 여유로운 아침 및 출국
#
# - **오전**
#   - 여유롭게 아침 식사 후, 하노이 시내의 카페에서 커피 한 잔 즐기기
#   - 마지막 기념품 쇼핑
#
# - **점심**
#   - 체크아웃 후 공항으로 가기 전 가벼운 점심
#
# - **출국**
#   - 공항으로 이동 및 비행기 탑승
#
# 이 일정은 여행자의 흥미와 필요에 따라 조정할 수 있습니다. 안전하고 즐거운 여행 되세요!
